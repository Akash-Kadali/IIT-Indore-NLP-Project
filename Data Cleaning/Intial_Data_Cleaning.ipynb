# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

df_users = pd.read_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_1.csv/users.csv")
df_users
# Out:
#              id                 name      screen_name  statuses_count  \
# 0      24858289       Davide Bertoli        davideb66            1299
# 1      33212890       Elisa D'Ospina     ElisaDospina           18665
# 2      39773427      Donato Vincenzo       Vladimir65           22987
# 3      57007623   Rafiela Morales L.   RafielaMorales            7975
# 4      63258466         § h a † u r♄      FabrizioC_c           20218
# ..          ...                  ...              ...             ...
# 986  2286273170              falomar     paolofalomar             450
# 987  2287318956         Marco Nuovoi      marconuovoi             460
# 988  2290264806                 Enzo    enzocolecchia             485
# 989  2398910547      Southern Fields  southern_fields             730
# 990  2525273432  CHIARA PERISSINOTTO        chianotto              85
#
#      followers_count  friends_count  favourites_count  listed_count  \
# ...

# %%
import pandas as pd

# Specify the encoding parameter when reading the CSV file
df_tweets = pd.read_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_1.csv/tweets.csv", encoding='latin1')
# Print the header of the DataFrame
print(df_tweets.head())
# Out:
# <ipython-input-5-ab3fc6602cec>:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tweets = pd.read_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_1.csv/tweets.csv", encoding='latin1')
#                    id                                               text  \
# 0  532627591686275072   I Pooh - In silenzio 1968 http://t.co/ahvQxUqTws
# 1  532624255058706432                             http://t.co/HyI5EQKz6Q
# 2  532513524460052480  Tutti a tavola, con il filetto di baccalÃ . ht...
# 3  532297646669852672                             http://t.co/NAHQ4l2pUy
# 4  532295960807100416       Gold - Spandau Ballet http://t.co/o8ZJHt7Neu
#
#                                               source   user_id  truncated  \
# 0  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
# 1  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
# ...

# %%
df_tweets
# Out:
#                          id  \
# 0        532627591686275072
# 1        532624255058706432
# 2        532513524460052480
# 3        532297646669852672
# 4        532295960807100416
# ...                     ...
# 1610029  470953862489468928
# 1610030  470953620155158528
# 1610031  470953572868562945
# 1610032  470953492358901760
# 1610033  470953465309822977
#
#                                                       text  \
# 0         I Pooh - In silenzio 1968 http://t.co/ahvQxUqTws
# 1                                   http://t.co/HyI5EQKz6Q
# 2        Tutti a tavola, con il filetto di baccalÃ . ht...
# 3                                   http://t.co/NAHQ4l2pUy
# 4             Gold - Spandau Ballet http://t.co/o8ZJHt7Neu
# ...                                                    ...
# 1610029  "La fantasia Ã¨ la figlia diletta della libert...
# 1610030  RT @Piovegovernolad: INGHILTERRA: FARAGE LI HA...
# 1610031  RT @Piovegovernolad: Kyenge eletta: "Rappresen...
# ...

# %%
# Print column headers
print(df_tweets.columns)
# Out:
# Index(['id', 'text', 'source', 'user_id', 'truncated', 'in_reply_to_status_id',
#        'in_reply_to_user_id', 'in_reply_to_screen_name', 'retweeted_status_id',
#        'geo', 'place', 'contributors', 'retweet_count', 'reply_count',
#        'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive',
#        'num_hashtags', 'num_urls', 'num_mentions', 'created_at', 'timestamp',
#        'crawled_at', 'updated'],
#       dtype='object')

# %%
import pandas as pd

columns_to_keep = ['id', 'text', 'user_id', 'retweet_count', 'reply_count', 'possibly_sensitive','num_hashtags', 'num_urls']

# Creating new DataFrame with selected columns
new_df_tweets = df_tweets[columns_to_keep]

# Print the header of the new DataFrame
new_df_tweets
# Out:
#                          id  \
# 0        532627591686275072
# 1        532624255058706432
# 2        532513524460052480
# 3        532297646669852672
# 4        532295960807100416
# ...                     ...
# 1610029  470953862489468928
# 1610030  470953620155158528
# 1610031  470953572868562945
# 1610032  470953492358901760
# 1610033  470953465309822977
#
#                                                       text     user_id  \
# 0         I Pooh - In silenzio 1968 http://t.co/ahvQxUqTws    24858289
# 1                                   http://t.co/HyI5EQKz6Q    24858289
# 2        Tutti a tavola, con il filetto di baccalÃ . ht...    24858289
# 3                                   http://t.co/NAHQ4l2pUy    24858289
# 4             Gold - Spandau Ballet http://t.co/o8ZJHt7Neu    24858289
# ...                                                    ...         ...
# 1610029  "La fantasia Ã¨ la figlia diletta della libert...  2525273432
# ...

# %%
new_df_tweets.to_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_1.csv/new_tweets.csv")

# %%
# Print column headers
print(df_users.columns)
# Out:
# Index(['id', 'name', 'screen_name', 'statuses_count', 'followers_count',
#        'friends_count', 'favourites_count', 'listed_count', 'url', 'lang',
#        'time_zone', 'location', 'default_profile', 'default_profile_image',
#        'geo_enabled', 'profile_image_url', 'profile_banner_url',
#        'profile_use_background_image', 'profile_background_image_url_https',
#        'profile_text_color', 'profile_image_url_https',
#        'profile_sidebar_border_color', 'profile_background_tile',
#        'profile_sidebar_fill_color', 'profile_background_image_url',
#        'profile_background_color', 'profile_link_color', 'utc_offset',
#        'is_translator', 'follow_request_sent', 'protected', 'verified',
#        'notifications', 'description', 'contributors_enabled', 'following',
#        'created_at', 'timestamp', 'crawled_at', 'updated', 'test_set_1'],
#       dtype='object')

# %%
import pandas as pd

columns_to_keep_users = ['id','screen_name', 'statuses_count', 'followers_count',
                         'friends_count', 'favourites_count', 'listed_count', 'url',
                         'lang','description']

# Creating new DataFrame with selected columns
new_df_users = df_users[columns_to_keep_users]

# Print the header of the new DataFrame
new_df_users
# Out:
#              id      screen_name  statuses_count  followers_count  \
# 0      24858289        davideb66            1299               22
# 1      33212890     ElisaDospina           18665            12561
# 2      39773427       Vladimir65           22987              600
# 3      57007623   RafielaMorales            7975              398
# 4      63258466      FabrizioC_c           20218              413
# ..          ...              ...             ...              ...
# 986  2286273170     paolofalomar             450             4455
# 987  2287318956      marconuovoi             460             3731
# 988  2290264806    enzocolecchia             485             4669
# 989  2398910547  southern_fields             730             1132
# 990  2525273432        chianotto              85              963
#
#      friends_count  favourites_count  listed_count                     url  \
# 0               40                 1             0                     NaN
# ...

# %%
new_df_users.to_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_1.csv/new_users.csv")

# %%
import pandas as pd

df_tweets_2 = pd.read_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_2.csv/tweets.csv", encoding='latin1')
df_tweets_2
# Out:
# <ipython-input-17-4c963510b9fe>:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tweets_2 = pd.read_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_2.csv/tweets.csv", encoding='latin1')
#                         id                                               text  \
# 0       532613365307547649   Mother daughter java time http://t.co/iPNFLGY2dA
# 1       532596235296071682  #NSFW XXX pics and preview vids from the Den o...
# 2       532547526705311744  Blkmlwaukeetgirl Gabor and I am still single h...
# 3       532540434405662721  House To House Feat. Kym Mazelle - Taste My Lo...
# 4       532537413525323776  Before WBMX, before many Chicagoans knew about...
# ...                    ...                                                ...
# 428537  450310417693540352  I'm a sinner, who prolly gone sin again, lord ...
# 428538  450310101128445952                                                NaN
# ...

# %%
import pandas as pd

columns_to_keep = ['id', 'text', 'user_id', 'retweet_count', 'reply_count', 'possibly_sensitive','num_hashtags', 'num_urls']

# Creating new DataFrame with selected columns
new_df_tweets_2 = df_tweets_2[columns_to_keep]

# Print the header of the new DataFrame
new_df_tweets_2
# Out:
#                         id                                               text  \
# 0       532613365307547649   Mother daughter java time http://t.co/iPNFLGY2dA
# 1       532596235296071682  #NSFW XXX pics and preview vids from the Den o...
# 2       532547526705311744  Blkmlwaukeetgirl Gabor and I am still single h...
# 3       532540434405662721  House To House Feat. Kym Mazelle - Taste My Lo...
# 4       532537413525323776  Before WBMX, before many Chicagoans knew about...
# ...                    ...                                                ...
# 428537  450310417693540352  I'm a sinner, who prolly gone sin again, lord ...
# 428538  450310101128445952                                                NaN
# 428539  450309994911907840  Aight so I do a weekly/ bi weekly play list an...
# 428540  450309661523443712  #YouGoochiePoochie6 by Radio Reek http://t.co/...
# 428541  450309405972914176  Had to jump back on twitter .. RADIO REEK .. #...
#
# ...

# %%
new_df_tweets_2.to_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_2.csv/new_tweets_2.csv")

# %%
import pandas as pd
import numpy as np

df_users_2 = pd.read_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_2.csv/users.csv")
df_users_2

columns_to_keep_users = ['id','screen_name', 'statuses_count', 'followers_count',
                         'friends_count', 'favourites_count', 'listed_count', 'url',
                         'lang','description']

# Creating new DataFrame with selected columns
new_df_users_2 = df_users_2[columns_to_keep_users]

# Print the header of the new DataFrame
new_df_users_2
# Out:
#               id     screen_name  statuses_count  followers_count  \
# 0     2372241176  DennaMcsparren              53               10
# 1     2368684734   YukikoTretter              68                4
# 2     2353855646     RochelAmaro              79                9
# 3     2372322542     BrandiBabin              59                1
# 4     2352506778    ChungPosadas              73                7
# ...          ...             ...             ...              ...
# 3452  2349367388     RubyPorchia             221               59
# 3453  2391867347     MasudThomas              20                6
# 3454  2357512092      RhondaHoes              51                4
# 3455  2349689623         MaeAsif             283              105
# 3456  2357961930    YvonneHarpel              50                6
#
#       friends_count  favourites_count  listed_count  url lang description
# 0                46                 0             0  NaN   en         NaN
# ...

# %%
new_df_users_2.to_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_2.csv/new_users_2.csv")

# %%
import pandas as pd

df_tweets_3 = pd.read_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_3.csv/tweets.csv", encoding='latin1')
df_tweets_3

columns_to_keep = ['id', 'text', 'user_id', 'retweet_count', 'reply_count', 'possibly_sensitive','num_hashtags', 'num_urls']

# Creating new DataFrame with selected columns
new_df_tweets_3 = df_tweets_3[columns_to_keep]

# Print the header of the new DataFrame
new_df_tweets_3
# Out:
# <ipython-input-23-fa2518c829ad>:3: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tweets_3 = pd.read_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_3.csv/tweets.csv", encoding='latin1')
#                          id  \
# 0        532626057124651008
# 1        532625740693766144
# 2        532624176276721665
# 3        532623364418838528
# 4        532623136051564546
# ...                     ...
# 1418552  454798224193110016
# 1418553  454797453150011392
# 1418554  454795927169929216
# 1418555  454794149791666176
# 1418556  454792875612438530
#
#                                                       text     user_id  \
# 0        Am postat o fotografie nouÄ pe Facebook http:...    16282004
# 1        Am postat o fotografie nouÄ pe Facebook http:...    16282004
# 2        Today's Joke - The dogs ask each other what th...    16282004
# 3        Today's Inspirational Quote Bloom where you ar...    16282004
# ...

# %%
new_df_tweets_3.to_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_3.csv/new_tweets_3.csv")

# %%
import pandas as pd
import numpy as np

df_users_3 = pd.read_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_3.csv/users.csv")
df_users_3

columns_to_keep_users = ['id','screen_name', 'statuses_count', 'followers_count',
                         'friends_count', 'favourites_count', 'listed_count', 'url',
                         'lang','description']

# Creating new DataFrame with selected columns
new_df_users_3 = df_users_3[columns_to_keep_users]

# Print the header of the new DataFrame
new_df_users_3
new_df_users_3.to_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_3.csv/new_users_3.csv")

# %%
# Concatenate the dataframes vertically
merged_df = pd.concat([new_df_users, new_df_users_2, new_df_users_3])

# Display the merged dataframe
merged_df.to_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_users.csv")

# %%
# Concatenate the dataframes vertically
merged_df = pd.concat([new_df_tweets, new_df_tweets_2, new_df_tweets_3])

# Display the merged dataframe
merged_df.to_csv("/content/drive/MyDrive/MiB Dataset/social_spambots_tweets.csv")

# %%
import pandas as pd
import numpy as np

df_real_users = pd.read_csv("/content/drive/MyDrive/MiB Dataset/genuine_accounts.csv/users.csv")
df_real_users

columns_to_keep_users = ['id','screen_name', 'statuses_count', 'followers_count',
                         'friends_count', 'favourites_count', 'listed_count', 'url',
                         'lang','description']

# Creating new DataFrame with selected columns
new_df_real_users= df_real_users[columns_to_keep_users]

# Print the header of the new DataFrame
new_df_real_users
new_df_real_users.to_csv("/content/drive/MyDrive/MiB Dataset/real_users.csv")
