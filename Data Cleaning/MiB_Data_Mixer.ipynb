# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

df_spam_users = pd.read_csv("/content/drive/MyDrive/MiB Dataset/type_spam_users.csv")
df_spam_tweets = pd.read_csv("/content/drive/MyDrive/MiB Dataset/type_spam_tweets.csv")
# Out:
# Mounted at /content/drive

# %%
df_spam_users = df_spam_users.drop("Unnamed: 0", axis = 1)
df_spam_tweets = df_spam_tweets.drop("Unnamed: 0", axis = 1)

# %%
df_spam_tweets.columns
# Out:
# Index(['id', 'text', 'user_id', 'retweet_count', 'reply_count',
#        'possibly_sensitive', 'num_hashtags', 'num_urls', 'type'],
#       dtype='object')

# %%
df_spam_users.columns
# Out:
# Index(['id', 'screen_name', 'statuses_count', 'followers_count',
#        'friends_count', 'favourites_count', 'listed_count', 'url', 'lang',
#        'description', 'type'],
#       dtype='object')

# %%
df_spam_tweets
# Out:
#                          id  \
# 0        516713829125079040
# 1        487502621696335873
# 2        526518861378899968
# 3        499313209455939584
# 4        510981086181351424
# ...                     ...
# 3602222  464880205015035904
# 3602223  487878851662725120
# 3602224  446039784054865920
# 3602225  459202626618667008
# 3602226  527946231327494144
#
#                                                       text    user_id  \
# 0        Adornment, what a science! Beauty, what a weap...  953307336
# 1        -Nasci -Cresci -Ti iscrivi a Twitter  -Conosci...  466370213
# 2        Read the fascinating history of the Boston Red...  531218934
# 3        Hanno creato un social e il social ha creato d...  539157095
# 4        I love any movie that has a retarded person wo...  297565762
# ...                                                    ...        ...
# 3602222  "Entrepreneurs don't waste time/energy worryin...  159797667
# ...

# %%
df_spam_users
# Out:
#               id      screen_name  statuses_count  followers_count  \
# 0      373449731      tmj_ND_UTIL               3              282
# 1      314162343      tmj_OH_UTIL               3              290
# 2       71721845   tmj_chh_cstsrv             195              316
# 3      466165783  LuciaBiricchina             139              386
# 4       84640693       karengioti              39              628
# ...          ...              ...             ...              ...
# 7538  2362055604      CathyWasher              47                8
# 7539   468089119   DanielaGalucci             133              250
# 7540    23213373   tmj_bal_itjava              12              235
# 7541   632185151     tmj_mex_mgmt               4              217
# 7542   465393290   RenzoMeravigli              68                0
#
#       friends_count  favourites_count  listed_count                      url  \
# 0               280                 0             2   http://t.co/whU1ZBGYRl
# ...

# %%
total_unique_ids = df_spam_tweets['user_id'].nunique()
print("Total unique ids:", total_unique_ids)
# Out:
# Total unique ids: 5912

# %%
total_unique_ids_2 = df_spam_users['id'].nunique()
print("Total unique ids:", total_unique_ids_2)
# Out:
# Total unique ids: 7543

# %%
import pandas as pd

# Rename the 'id' column to 'user_id' in df_spam_users
df_spam_users.rename(columns={'id': 'user_id'}, inplace=True)

# Perform inner join with renamed column
inner_join_df = pd.merge(df_spam_tweets, df_spam_users, on='user_id', how='outer')

# Display the inner join result
inner_join_df
# Out:
#                    id                                               text  \
# 0        5.167138e+17  Adornment, what a science! Beauty, what a weap...
# 1        5.165821e+17  Gotta love this Minecraft wall torch - http://...
# 2        5.238680e+17  I did not have three thousand pairs of shoes, ...
# 3        5.111610e+17  The person who doesn't know where his next dol...
# 4        5.137319e+17  There are so many emotions involved that I wou...
# ...               ...                                                ...
# 3603853           NaN                                                NaN
# 3603854           NaN                                                NaN
# 3603855           NaN                                                NaN
# 3603856           NaN                                                NaN
# 3603857           NaN                                                NaN
#
#             user_id  retweet_count  reply_count  possibly_sensitive  \
# ...

# %%
inner_join_df = inner_join_df.drop("type_x", axis = 1)
inner_join_df
# Out:
#                                                       text     user_id  \
# 0        Adornment, what a science! Beauty, what a weap...   953307336
# 1        Gotta love this Minecraft wall torch - http://...   953307336
# 2        I did not have three thousand pairs of shoes, ...   953307336
# 3        The person who doesn't know where his next dol...   953307336
# 4        There are so many emotions involved that I wou...   953307336
# ...                                                    ...         ...
# 3603853                                                NaN    42157521
# 3603854                                                NaN   563032766
# 3603855                                                NaN  2370172489
# 3603856                                                NaN    23213373
# 3603857                                                NaN   632185151
#
#          retweet_count  reply_count  possibly_sensitive  num_hashtags  \
# ...

# %%
import pandas as pd

# Rename the 'id' column to 'user_id' in df_spam_users
inner_join_df.rename(columns={'type_y': 'type'}, inplace=True)

# Display the inner join result
inner_join_df
# Out:
#                                                       text     user_id  \
# 0        Adornment, what a science! Beauty, what a weap...   953307336
# 1        Gotta love this Minecraft wall torch - http://...   953307336
# 2        I did not have three thousand pairs of shoes, ...   953307336
# 3        The person who doesn't know where his next dol...   953307336
# 4        There are so many emotions involved that I wou...   953307336
# ...                                                    ...         ...
# 3603853                                                NaN    42157521
# 3603854                                                NaN   563032766
# 3603855                                                NaN  2370172489
# 3603856                                                NaN    23213373
# 3603857                                                NaN   632185151
#
#          retweet_count  reply_count  possibly_sensitive  num_hashtags  \
# ...

# %%
inner_join_df.to_csv("/content/drive/MyDrive/MiB Dataset/mega_users.csv")

# %%
# Perform inner join with renamed column
inner_join_df_new = pd.merge(df_spam_tweets, df_spam_users, on='user_id', how='inner')
inner_join_df_new
# Out:
#                          id  \
# 0        516713829125079040
# 1        516582111005143040
# 2        523868043966164992
# 3        511160961982803968
# 4        513731858019155968
# ...                     ...
# 3602222          4586142268
# 3602223          3453175754
# 3602224           211459699
# 3602225          4781363843
# 3602226          3497544173
#
#                                                       text    user_id  \
# 0        Adornment, what a science! Beauty, what a weap...  953307336
# 1        Gotta love this Minecraft wall torch - http://...  953307336
# 2        I did not have three thousand pairs of shoes, ...  953307336
# 3        The person who doesn't know where his next dol...  953307336
# 4        There are so many emotions involved that I wou...  953307336
# ...                                                    ...        ...
# 3602222           hey comment my pix \n http://urly.at/5cL   79354105
# ...

# %%
inner_join_df_new = inner_join_df_new.drop("type_x", axis = 1)
inner_join_df_new
# Out:
#                          id  \
# 0        516713829125079040
# 1        516582111005143040
# 2        523868043966164992
# 3        511160961982803968
# 4        513731858019155968
# ...                     ...
# 3602222          4586142268
# 3602223          3453175754
# 3602224           211459699
# 3602225          4781363843
# 3602226          3497544173
#
#                                                       text    user_id  \
# 0        Adornment, what a science! Beauty, what a weap...  953307336
# 1        Gotta love this Minecraft wall torch - http://...  953307336
# 2        I did not have three thousand pairs of shoes, ...  953307336
# 3        The person who doesn't know where his next dol...  953307336
# 4        There are so many emotions involved that I wou...  953307336
# ...                                                    ...        ...
# 3602222           hey comment my pix \n http://urly.at/5cL   79354105
# ...

# %%
import pandas as pd

# Rename the 'id' column to 'user_id' in df_spam_users
inner_join_df_new.rename(columns={'type_y': 'type'}, inplace=True)

# Display the inner join result
inner_join_df_new
# Out:
#                          id  \
# 0        516713829125079040
# 1        516582111005143040
# 2        523868043966164992
# 3        511160961982803968
# 4        513731858019155968
# ...                     ...
# 3602222          4586142268
# 3602223          3453175754
# 3602224           211459699
# 3602225          4781363843
# 3602226          3497544173
#
#                                                       text    user_id  \
# 0        Adornment, what a science! Beauty, what a weap...  953307336
# 1        Gotta love this Minecraft wall torch - http://...  953307336
# 2        I did not have three thousand pairs of shoes, ...  953307336
# 3        The person who doesn't know where his next dol...  953307336
# 4        There are so many emotions involved that I wou...  953307336
# ...                                                    ...        ...
# 3602222           hey comment my pix \n http://urly.at/5cL   79354105
# ...

# %%
inner_join_df_new = inner_join_df_new.drop("id", axis = 1)
inner_join_df_new
# Out:
#                                                       text    user_id  \
# 0        Adornment, what a science! Beauty, what a weap...  953307336
# 1        Gotta love this Minecraft wall torch - http://...  953307336
# 2        I did not have three thousand pairs of shoes, ...  953307336
# 3        The person who doesn't know where his next dol...  953307336
# 4        There are so many emotions involved that I wou...  953307336
# ...                                                    ...        ...
# 3602222           hey comment my pix \n http://urly.at/5cL   79354105
# 3602223  single guys???  comment me at \nhttp://xurl.jp...   67601742
# 3602224            pics from lastnight. http://xurl.jp/hxr   46322170
# 3602225   single guys?? hit me up at \nhttp://xurl.jp/1c6a   81056104
# 3602226             more pics of me \n http://xurl.jp/v71a   68195984
#
#          retweet_count  reply_count  possibly_sensitive  num_hashtags  \
# ...

# %%
inner_join_df_new.to_csv("/content/drive/MyDrive/MiB Dataset/mega_spam_tweets.csv")
